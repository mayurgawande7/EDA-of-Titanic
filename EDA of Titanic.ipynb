# %% [markdown]
# ### EDA OF TITANIC

# %%
import numpy as np
from pandas import DataFrame,Series
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
a= sns.load_dataset('titanic')

# %%
a
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
a.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
a.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
a.shape
# Out:
# (891, 15)

# %%
a.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
a.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
a.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
# survived       891 non-null int64
# pclass         891 non-null int64
# sex            891 non-null object
# age            714 non-null float64
# sibsp          891 non-null int64
# parch          891 non-null int64
# fare           891 non-null float64
# embarked       889 non-null object
# class          891 non-null category
# who            891 non-null object
# adult_male     891 non-null bool
# deck           203 non-null category
# embark_town    889 non-null object
# alive          891 non-null object
# alone          891 non-null bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
a.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
a['age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
a["alive"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
a["alive"].count()
# Out:
# 891

# %%
a['class'].unique()
# Out:
# [Third, First, Second]
# Categories (3, object): [Third, First, Second]

# %%
a['survived'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
a['survived'].count()
# Out:
# 891

# %%
a.groupby('survived').count()
# Out:
#           pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# survived
# 0            549  549  424    549    549   549       549    549  549
# 1            342  342  290    342    342   342       340    342  342
#
#           adult_male  deck  embark_town  alive  alone
# survived
# 0                549    67          549    549    549
# 1                342   136          340    342    342

# %%
a['age'].groupby(a['survived']).mean()
# Out:
# survived
# 0    30.626179
# 1    28.343690
# Name: age, dtype: float64

# %%
s = Series(a['age'].groupby(a['survived']).count())
s
# Out:
# survived
# 0    424
# 1    290
# Name: age, dtype: int64

# %%
Survived = ['Yes','No']

# %%
plt.bar(Survived,s,label='Data')
plt.ylabel('Count')
plt.xlabel('Survived ')
plt.title('Bar Graph for titanic survivels')
plt.legend()
plt.show()

# %%
df = DataFrame(a.dtypes)
df
# Out:
#                     0
# survived        int64
# pclass          int64
# sex            object
# age           float64
# sibsp           int64
# parch           int64
# fare          float64
# embarked       object
# class        category
# who            object
# adult_male       bool
# deck         category
# embark_town    object
# alive          object
# alone            bool

# %%
df["missingvalues"]=a.isnull().sum().sort_values(ascending=True)

# %%
df
# Out:
#                     0  missingvalues
# survived        int64              0
# pclass          int64              0
# sex            object              0
# age           float64            177
# sibsp           int64              0
# parch           int64              0
# fare          float64              0
# embarked       object              2
# class        category              0
# who            object              0
# adult_male       bool              0
# deck         category            688
# embark_town    object              2
# alive          object              0
# alone            bool              0

# %%
a.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# deck           688
# age            177
# embark_town      2
# embarked         2
# alone            0
# alive            0
# adult_male       0
# who              0
# class            0
# fare             0
# dtype: int64

# %%
df["uniquevalues"]=a.nunique()

# %%
df
# Out:
#                     0  missingvalues  uniquevalues
# survived        int64              0             2
# pclass          int64              0             3
# sex            object              0             2
# age           float64            177            88
# sibsp           int64              0             7
# parch           int64              0             7
# fare          float64              0           248
# embarked       object              2             3
# class        category              0             3
# who            object              0             3
# adult_male       bool              0             2
# deck         category            688             7
# embark_town    object              2             3
# alive          object              0             2
# alone            bool              0             2

# %%
df['Count']=a.count()
df
# Out:
#                     0  missingvalues  uniquevalues  Count
# survived        int64              0             2    891
# pclass          int64              0             3    891
# sex            object              0             2    891
# age           float64            177            88    714
# sibsp           int64              0             7    891
# parch           int64              0             7    891
# fare          float64              0           248    891
# embarked       object              2             3    889
# class        category              0             3    891
# who            object              0             3    891
# adult_male       bool              0             2    891
# deck         category            688             7    203
# embark_town    object              2             3    889
# alive          object              0             2    891
# alone            bool              0             2    891

# %%
s1 = Series(a['age'].groupby(a['pclass']).count())
s1
# Out:
# pclass
# 1    186
# 2    173
# 3    355
# Name: age, dtype: int64

# %%
l2 = ['First Class','Second Class','Third Class']

# %%
plt.bar(l2,s1,label='Data')
plt.ylabel('Count')
plt.xlabel('travelclass ')
plt.title('Distribution for travelling class')
plt.legend()
plt.show()

# %%
d =DataFrame(a.groupby(['pclass','survived']).mean())
d
# Out:
#                        age     sibsp     parch       fare  adult_male  \
# pclass survived
# 1      0         43.695312  0.287500  0.300000  64.684008    0.962500
#        1         35.368197  0.492647  0.389706  95.608029    0.308824
# 2      0         33.544444  0.319588  0.144330  19.412328    0.938144
#        1         25.901566  0.494253  0.643678  22.055700    0.091954
# 3      0         26.555556  0.672043  0.384409  13.669364    0.755376
#        1         20.646118  0.436975  0.420168  13.694887    0.319328
#
#                     alone
# pclass survived
# 1      0         0.637500
#        1         0.426471
# 2      0         0.701031
#        1         0.413793
# 3      0         0.685484
#        1         0.579832

# %%
d['fare']
# Out:
# pclass  survived
# 1       0           64.684008
#         1           95.608029
# 2       0           19.412328
#         1           22.055700
# 3       0           13.669364
#         1           13.694887
# Name: fare, dtype: float64

# %%
d['age']
# Out:
# pclass  survived
# 1       0           43.695312
#         1           35.368197
# 2       0           33.544444
#         1           25.901566
# 3       0           26.555556
#         1           20.646118
# Name: age, dtype: float64

# %%
d = d.swaplevel(0)
d
# Out:
#                        age     sibsp     parch       fare  adult_male  \
# survived pclass
# 0        1       43.695312  0.287500  0.300000  64.684008    0.962500
# 1        1       35.368197  0.492647  0.389706  95.608029    0.308824
# 0        2       33.544444  0.319588  0.144330  19.412328    0.938144
# 1        2       25.901566  0.494253  0.643678  22.055700    0.091954
# 0        3       26.555556  0.672043  0.384409  13.669364    0.755376
# 1        3       20.646118  0.436975  0.420168  13.694887    0.319328
#
#                     alone
# survived pclass
# 0        1       0.637500
# 1        1       0.426471
# 0        2       0.701031
# 1        2       0.413793
# 0        3       0.685484
# 1        3       0.579832

# %%
d.sort_index(0)
# Out:
#                        age     sibsp     parch       fare  adult_male  \
# survived pclass
# 0        1       43.695312  0.287500  0.300000  64.684008    0.962500
#          2       33.544444  0.319588  0.144330  19.412328    0.938144
#          3       26.555556  0.672043  0.384409  13.669364    0.755376
# 1        1       35.368197  0.492647  0.389706  95.608029    0.308824
#          2       25.901566  0.494253  0.643678  22.055700    0.091954
#          3       20.646118  0.436975  0.420168  13.694887    0.319328
#
#                     alone
# survived pclass
# 0        1       0.637500
#          2       0.701031
#          3       0.685484
# 1        1       0.426471
#          2       0.413793
#          3       0.579832

# %%
d.sum(level=1)
# Out:
#               age     sibsp     parch        fare  adult_male     alone
# pclass
# 1       79.063509  0.780147  0.689706  160.292036    1.271324  1.063971
# 2       59.446011  0.813841  0.788008   41.468028    1.030098  1.114824
# 3       47.201673  1.109018  0.804577   27.364252    1.074704  1.265316

# %%
d.sum(level=0)
# Out:
#                  age     sibsp     parch        fare  adult_male     alone
# survived
# 0         103.795313  1.279131  0.828738   97.765700    2.656021  2.024015
# 1          81.915881  1.423875  1.453552  131.358616    0.720105  1.420096

# %%
Age= a['age'].dropna()

# %%
plt.hist(Age, bins=3,rwidth=0.95, color='g')
plt.xlabel("Age distribution ") 
plt.ylabel("Count of Travellers") 
plt.title("Different Ages") 
plt.show()

# %%
plt.hist(Age, bins=[0,18,45,80], rwidth=0.95, color='b',label='Age in Years')
plt.xlabel("Age") 
plt.ylabel("Number Of Travellers") 
plt.title("Count of Travellers vs Age Histogram") 
plt.legend()
plt.show()

# %%
plt.boxplot(Age)
plt.show()

# %%
plt.violinplot(Age)
plt.show()

# %%
sns.boxplot(a["fare"])
plt.show()

# %%
sns.distplot(a["fare"])
plt.show()
print("skiwness of fare",a["fare"].skew())
print("kurtosis of fare",a["fare"].kurt())
# Out:
# skiwness of fare 4.787316519674893
# kurtosis of fare 33.39814088089868

# %% [markdown]
# #### Zscore()

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(a["fare"]))
z
# Out:
# array([5.02445171e-01, 7.86845294e-01, 4.88854258e-01, 4.20730236e-01,
#        4.86337422e-01, 4.78116429e-01, 3.95813561e-01, 2.24083121e-01,
#        4.24256141e-01, 4.29555021e-02, 3.12172378e-01, 1.13845709e-01,
#        4.86337422e-01, 1.87093118e-02, 4.90279793e-01, 3.26266659e-01,
#        6.19988892e-02, 3.86670720e-01, 2.85997284e-01, 5.02948539e-01,
#        1.24919787e-01, 3.86670720e-01, 4.86756223e-01, 6.63597416e-02,
#        2.24083121e-01, 1.64441595e-02, 5.02948539e-01, 4.64700108e+00,
#        4.89776426e-01, 4.89442190e-01, 9.02720170e-02, 2.30172882e+00,
#        4.92377828e-01, 4.37007438e-01, 1.00606170e+00, 3.98582080e-01,
#        5.02863973e-01, 4.86337422e-01, 2.85997284e-01, 4.22073541e-01,
#        4.57645492e-01, 2.25593223e-01, 4.89442190e-01, 1.88762532e-01,
#        4.89776426e-01, 4.86337422e-01, 3.36334002e-01, 4.92377828e-01,
#        2.11917743e-01, 2.90024222e-01, 1.50673744e-01, 4.91371093e-01,
# ...

# %%
a["zscore"]=z

# %%
a.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone    zscore
# 0    man        True  NaN  Southampton    no  False  0.502445
# 1  woman       False    C    Cherbourg   yes  False  0.786845
# 2  woman       False  NaN  Southampton   yes   True  0.488854
# 3  woman       False    C  Southampton   yes  False  0.420730
# 4    man        True  NaN  Southampton    no   True  0.486337

# %%
(a["zscore"]>=3).sum()
# Out:
# 20

# %%
az=a[a["zscore"]<3]
az
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
a.shape
# Out:
# (891, 16)

# %%
az.shape
# Out:
# (871, 16)

# %%
az.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  871.000000  871.000000  696.000000  871.000000  871.000000  871.000000
# mean     0.376579    2.338691   29.661164    0.517796    0.366246   26.530170
# std      0.484806    0.821469   14.571894    1.101448    0.792325   29.351184
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   13.862500
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   30.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  164.866700
#
#            zscore
# count  871.000000
# mean     0.465843
# std      0.380869
# min      0.002348
# 25%      0.278447
# 50%      0.460162
# 75%      0.492378
# max      2.671118

# %%
sns.distplot(az["fare"])
plt.show()
print("skiwness of fare",az["fare"].skew())
print("kurtosis of fare",az["fare"].kurt())
# Out:
# skiwness of fare 2.250998592424474
# kurtosis of fare 5.304249897460028

# %%
sns.boxplot(az["fare"])
plt.show()

# %%
q2=a["fare"].median()
q2
# Out:
# 14.4542

# %%
q1=a["fare"].quantile(0.25)
q1
# Out:
# 7.9104

# %%
q3=a["fare"].quantile(0.75)
q3
# Out:
# 31.0

# %% [markdown]
# ### IQR()

# %%
iqr=q3-q1
iqr
# Out:
# 23.0896

# %%
ai=a[~((a["fare"]<(q1-1.5*iqr))|(a["fare"]>(q3+1.5*iqr)))]
ai
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 5           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
sns.boxplot(ai["fare"])

# %%
sns.distplot(ai['fare'])
plt.show()

# %%
a.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
# zscore      0.156602 -0.312888  0.059908 -0.003555  0.062829  0.911083
#
#             adult_male     alone    zscore
# survived     -0.557080 -0.203367  0.156602
# pclass        0.094035  0.135207 -0.312888
# age           0.280328  0.198270  0.059908
# sibsp        -0.253586 -0.584471 -0.003555
# ...

# %%
corr=a.corr()["fare"]
corr
# Out:
# survived      0.257307
# pclass       -0.549500
# age           0.096067
# sibsp         0.159651
# parch         0.216225
# fare          1.000000
# adult_male   -0.182024
# alone        -0.271832
# zscore        0.911083
# Name: fare, dtype: float64

# %%
goodcorr=corr[corr>0.5].sort_values(ascending=False)
goodcorr
# Out:
# fare      1.000000
# zscore    0.911083
# Name: fare, dtype: float64
